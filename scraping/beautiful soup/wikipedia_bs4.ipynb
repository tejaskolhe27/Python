# %%
import time
import requests
from bs4 import BeautifulSoup
import csv

start_url = 'https://en.wikipedia.org/wiki/Academy_Award_for_Best_Picture'

csv_file = open('movie_data.csv', 'w', newline='', encoding='utf-8')
csv_writer = csv.DictWriter(csv_file, fieldnames=['TITLE', 'DIRECTED BY', 'RELEASE DATE'])
csv_writer.writeheader()

response = requests.get(start_url)

soup = BeautifulSoup(response.text, 'html.parser')

movie_links = soup.select("tr[style='background:#FAEB86'] a[href*='film)']")

for link in movie_links:
        
      
        movie_url = 'https://en.wikipedia.org' + link['href']
        movie_response = requests.get(movie_url)
        movie_soup = BeautifulSoup(movie_response.text, 'html.parser')
        title = movie_soup.select_one("h1[id='firstHeading'] i").get_text()
        directed_by = [director.get_text() for director in movie_soup.select("tr:contains('Directed by') a[href*='/wiki/']")]
        release_dates = [date.get_text() for date in movie_soup.select(r"tr:contains('Release dates') span ")]
        data = {
                'TITLE': title,
                'DIRECTED BY': directed_by,
                'RELEASE DATE': release_dates,
            }
        csv_writer.writerow(data)
        print(f"Scraped data for: {title}")
        time.sleep(2)

# Close the CSV file
csv_file.close()
# Out:
# Scraped data for: Wings
# Scraped data for: All Quiet on the Western Front
# Scraped data for: Cimarron
# Scraped data for: Grand Hotel
# Scraped data for: Cavalcade
# Scraped data for: Mutiny on the Bounty
# Scraped data for: You Can't Take It with You
# Scraped data for: Gone with the Wind
# Scraped data for: Rebecca
# Scraped data for: How Green Was My Valley
# Scraped data for: Casablanca
# Scraped data for: The Lost Weekend
# Scraped data for: Hamlet
# Scraped data for: All the King's Men
# Scraped data for: An American in Paris
# Scraped data for: The Greatest Show on Earth
# Scraped data for: Marty
# Scraped data for: Around the World in 80 Days
# Scraped data for: Gigi
# Scraped data for: Ben-Hur
# Scraped data for: West Side Story
# Scraped data for: Lawrence of Arabia
# Scraped data for: Tom Jones
# Scraped data for: My Fair Lady
# Scraped data for: The Sound of Music
# Scraped data for: A Man for All Seasons
# Scraped data for: In the Heat of the Night
# Scraped data for: Oliver!
# Scraped data for: Patton
# Scraped data for: The French Connection
# Scraped data for: One Flew Over the Cuckoo's Nest
# Scraped data for: Gandhi
# Scraped data for: Amadeus
# Scraped data for: Out of Africa
# Scraped data for: Platoon
# Scraped data for: The Silence of the Lambs
# Scraped data for: The English Patient
# Scraped data for: Titanic
# Scraped data for: American Beauty
# Scraped data for: Gladiator
# Scraped data for: A Beautiful Mind
# Scraped data for: Chicago
# Scraped data for: Crash
# Scraped data for: The Artist
# Scraped data for: Argo
# Scraped data for: 12 Years a Slave
# Scraped data for: Birdman
# Scraped data for: Spotlight
# Scraped data for: Moonlight
# Scraped data for: Green Book
# Scraped data for: Parasite
# Scraped data for: CODA
